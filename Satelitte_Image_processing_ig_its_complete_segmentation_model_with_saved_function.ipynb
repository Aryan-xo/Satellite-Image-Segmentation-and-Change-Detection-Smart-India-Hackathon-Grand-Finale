# %% [markdown]
# ```
# `# This is formatted as code`
# ```

# %%
# %env SM_FRAMEWORK=tf.keras
# Out:
# env: SM_FRAMEWORK=tf.keras

# %%
# !pip install patchify
# !pip install segmentation-models
# Out:
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from patchify) (1.23.5)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Collecting segmentation-models
#   Downloading segmentation_models-1.0.1-py3-none-any.whl (33 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from segmentation-models)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 3.8 MB/s eta 0:00:00
# Collecting image-classifiers==1.0.0 (from segmentation-models)
#   Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Collecting efficientnet==1.0.0 (from segmentation-models)
#   Downloading efficientnet-1.0.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.0.0->segmentation-models) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.23.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (3.9.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (3.2.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (9.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2023.9.26)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (23.2)
# Installing collected packages: keras-applications, image-classifiers, efficientnet, segmentation-models
# Successfully installed efficientnet-1.0.0 image-classifiers-1.0.0 keras-applications-1.0.8 segmentation-models-1.0.1

# %%
import os
import cv2
from PIL import Image
import numpy as np
import random
import json
import segmentation_models as sm
from patchify import patchify
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
#PART 2
import tensorflow as tf
from keras.models import Model
from keras.layers import Input,Conv2D,MaxPooling2D, Conv2DTranspose
from keras.layers import concatenate,BatchNormalization,Dropout,Lambda
from keras import backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Out:
# Segmentation Models: using `tf.keras` framework.

# %%
dire = "DUBAI/Semantic segmentation dataset"

# %%
# !unzip /content/Working_Segmentation.zip
# Out:
# Archive:  /content/Working_Segmentation.zip
#    creating: DUBAI/Semantic segmentation dataset/
#   inflating: DUBAI/Semantic segmentation dataset/classes.json
#    creating: DUBAI/Semantic segmentation dataset/Tile 1/
#    creating: DUBAI/Semantic segmentation dataset/Tile 1/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 1/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 1/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 2/
#    creating: DUBAI/Semantic segmentation dataset/Tile 2/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 2/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 2/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 3/
#    creating: DUBAI/Semantic segmentation dataset/Tile 3/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 3/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 3/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 4/
#    creating: DUBAI/Semantic segmentation dataset/Tile 4/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 4/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 4/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 5/
#    creating: DUBAI/Semantic segmentation dataset/Tile 5/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 5/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 5/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 6/
#    creating: DUBAI/Semantic segmentation dataset/Tile 6/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 6/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 6/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 7/
#    creating: DUBAI/Semantic segmentation dataset/Tile 7/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 7/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 7/masks/image_part_009.png
#    creating: DUBAI/Semantic segmentation dataset/Tile 8/
#    creating: DUBAI/Semantic segmentation dataset/Tile 8/images/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_001.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_002.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_003.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_004.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_005.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_006.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_007.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_008.jpg
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/images/image_part_009.jpg
#    creating: DUBAI/Semantic segmentation dataset/Tile 8/masks/
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_001.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_002.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_003.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_004.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_005.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_006.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_007.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_008.png
#   inflating: DUBAI/Semantic segmentation dataset/Tile 8/masks/image_part_009.png
#   inflating: SatelliteImageSegmentation_1.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_patch_size = 256

# %%
image_dataset = []
mask_dataset = []
for tile_id in range(1,7):
    for image_id in range(1,20):
        image = cv2.imread(f'{dire}/Tile {tile_id}/images/image_part_00{image_id}.jpg',1)
        mask = cv2.imread(f'{dire}/Tile {tile_id}/masks/image_part_00{image_id}.png',1)

        if image is not None:

            size_x = (image.shape[1]//image_patch_size)*image_patch_size
            size_y = (image.shape[0]//image_patch_size)*image_patch_size

            image = Image.fromarray(image)
            image = image.crop((0,0,size_x,size_y))
            image = np.array(image)
            patched_images = patchify(image,(image_patch_size,image_patch_size,3),step = image_patch_size)

            for i in range(patched_images.shape[0]):
                for j in range(patched_images.shape[1]):
                    individual_image = patched_images[i,j,:,:]

                    individual_image = MinMaxScaler().fit_transform(individual_image.reshape(-1,individual_image.shape[-1])).reshape(individual_image.shape)
                    individual_image = individual_image[0]

                    image_dataset.append(individual_image)

            mask = cv2.cvtColor(mask,cv2.COLOR_BGR2RGB)
            mask = Image.fromarray(mask)
            mask = mask.crop((0, 0, size_x, size_y))
            mask = np.array(mask)
            patched_masks = patchify(mask, (image_patch_size, image_patch_size, 3), step=image_patch_size)

            for i in range(patched_masks.shape[0]):
                for j in range(patched_masks.shape[1]):

                    individual_mask = patched_masks[i, j, :, :]
                    #individual_mask = MinMaxScaler().fit_transform(individual_mask.reshape(-1, individual_mask.shape[-1])).reshape(individual_mask.shape)
                    individual_mask = individual_mask[0]

                    mask_dataset.append(individual_mask)

# %%
print(len(image_dataset))
print(len(mask_dataset))
# Out:
# 441
# 441

# %%
random_image_id = random.randint(0,len(image_dataset))

plt.figure(figsize=(14,8))
plt.subplot(121)
plt.imshow(image_dataset[random_image_id])
plt.subplot(122)
plt.imshow(mask_dataset[random_image_id])

# %%
class_building = '#3C1098'
class_building = class_building.lstrip('#')
class_building = np.array(tuple(int(class_building[i:i+2], 16) for i in (0,2,4)))
print(class_building)

class_land = '#8429F6'
class_land = class_land.lstrip('#')
class_land = np.array(tuple(int(class_land[i:i+2], 16) for i in (0,2,4)))
print(class_land)

class_road = '#6EC1E4'
class_road = class_road.lstrip('#')
class_road = np.array(tuple(int(class_road[i:i+2], 16) for i in (0,2,4)))
print(class_road)

class_vegetation = '#FEDD3A'
class_vegetation = class_vegetation.lstrip('#')
class_vegetation = np.array(tuple(int(class_vegetation[i:i+2], 16) for i in (0,2,4)))
print(class_vegetation)

class_water = '#E2A929'
class_water = class_water.lstrip('#')
class_water = np.array(tuple(int(class_water[i:i+2], 16) for i in (0,2,4)))
print(class_water)

class_unlabeled = '#9B9B9B'
class_unlabeled = class_unlabeled.lstrip('#')
class_unlabeled = np.array(tuple(int(class_unlabeled[i:i+2], 16) for i in (0,2,4)))
print(class_unlabeled)
# Out:
# [ 60  16 152]
# [132  41 246]
# [110 193 228]
# [254 221  58]
# [226 169  41]
# [155 155 155]

# %%
def rgb_to_label(label):
  label_segment = np.zeros(label.shape, dtype=np.uint8)
  label_segment[np.all(label == class_water, axis=-1)] = 0
  label_segment[np.all(label == class_land, axis=-1)] = 1
  label_segment[np.all(label == class_road, axis=-1)] = 2
  label_segment[np.all(label == class_building, axis=-1)] = 3
  label_segment[np.all(label == class_vegetation, axis=-1)] = 4
  label_segment[np.all(label == class_unlabeled, axis=-1)] = 5
  #print(label_segment)
  label_segment = label_segment[:,:,0]
  #print(label_segment)
  return label_segment

# %%
mask_dataset_np = np.array(mask_dataset)
image_dataset_np = np.array(image_dataset)
labels = []
for i in range(mask_dataset_np.shape[0]):
  label = rgb_to_label(mask_dataset_np[i])
  labels.append(label)

# %%
#np.expand_dims(labels,axis=3)

random_image_id = random.randint(0,len(image_dataset))

plt.figure(figsize=(14,8))
plt.subplot(121)
plt.imshow(mask_dataset[random_image_id])
plt.subplot(122)
plt.imshow(labels[random_image_id])

# %%
total_classes = 6

# %%
#One hot encoded dataset
#For each pixel its label is represented as an array ex 3 is [0 0 1 0 0 0]
# 5 is [0 0 0 0 1 0]
labels_catagorical_dataset = to_categorical(labels,num_classes = total_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-13026394975e> in <cell line: 4>()
#       2 #For each pixel its label is represented as an array ex 3 is [0 0 1 0 0 0]
#       3 # 5 is [0 0 0 0 1 0]
# ----> 4 labels_catagorical_dataset = to_categorical(labels,num_classes = total_classes)
#
# NameError: name 'labels' is not defined

# %%
X_train,X_test ,y_train,y_test = train_test_split(image_dataset_np,labels_catagorical_dataset,test_size=0.2,random_state=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-337d26b05489> in <cell line: 1>()
# ----> 1 X_train,X_test ,y_train,y_test = train_test_split(image_dataset_np,labels_catagorical_dataset,test_size=0.2,random_state=100)
#
# NameError: name 'image_dataset_np' is not defined

# %%
def jaccard_coef(y_true,y_pred):
    y_true_flat = tf.keras.backend.flatten(y_true)
    y_pred_flat = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_flat*y_pred_flat)
    final_coef_value = (intersection +1.0)/(tf.keras.backend.sum(y_true_flat)+tf.keras.backend.sum(y_pred_flat)-intersection+1.0)
    return final_coef_value

# %%
def multi_Unet_model(num_classes,image_height=256,image_width=256,image_channels=3):
    inputs  = Input((image_height,image_width,image_channels))

    source_inputs = inputs

    c1 = Conv2D(filters = 16,kernel_size = (3,3),activation="relu",kernel_initializer="he_normal",padding="same")(source_inputs)
    c1 = Dropout(rate=0.2)(c1) #Dropout 20% of the data from c1
    c1 = Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c1)
    p1 = MaxPooling2D((2,2))(c1)

    c2 = Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p1)
    c2 = Dropout(rate=0.2)(c2) #Dropout 20% of the data from c1
    c2 = Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c2)
    p2 = MaxPooling2D((2,2))(c2)

    c3 = Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p2)
    c3 = Dropout(rate=0.2)(c3) #Dropout 20% of the data from c1
    c3 = Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c3)
    p3 = MaxPooling2D((2,2))(c3)

    c4 = Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p3)
    c4 = Dropout(rate=0.2)(c4) #Dropout 20% of the data from c1
    c4 = Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c4)
    p4 = MaxPooling2D((2,2))(c4)

    c5 = Conv2D(256,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(p4)
    c5 = Dropout(rate=0.2)(c5) #Dropout 20% of the data from c1
    c5 = Conv2D(256,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c5)

    u6 = Conv2DTranspose(128,(2,2),strides=(2,2),padding="same")(c5)
    u6 = concatenate([u6,c4])
    c6 = Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c6)

    u7 = Conv2DTranspose(64,(2,2),strides=(2,2),padding="same")(c6)
    u7 = concatenate([u7,c3])
    c7 = Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c7)


    u8 = Conv2DTranspose(32,(2,2),strides=(2,2),padding="same")(c7)
    u8 = concatenate([u8,c2])
    c8 = Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u8)
    c8 = Dropout(0.2)(c8)
    c8 = Conv2D(32,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c8)

    u9 = Conv2DTranspose(16,(2,2),strides=(2,2),padding="same")(c8)
    u9 = concatenate([u9,c1],axis=3)#NOTE axis changed
    c9 = Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(u9)
    c9 = Dropout(0.2)(c9)
    c9 = Conv2D(16,(3,3),activation="relu",kernel_initializer="he_normal",padding="same")(c9)

    outputs = Conv2D(num_classes,(1,1),activation="softmax")(c9)
    model = Model(inputs =[inputs],outputs=[outputs])

    return model

# %%
metrics = ["accuracy",jaccard_coef]
model = multi_Unet_model(total_classes,256,256,3)

# %%
# model.get_config()

# %%
#Loss function (Focal loss)(Cross entropy loss)
wieghts = [0.166,0.166,0.166,0.166,0.166,0.166]
dice_loss = sm.losses.DiceLoss(class_weights=wieghts)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1*focal_loss)

# %%
tf.keras.backend.clear_session()
model.compile(optimizer="adam",loss=total_loss,metrics=metrics)

# %%
# model.summary()

# %%
model_history = model.fit(X_train,y_train,batch_size=16,verbose=1,epochs=25,validation_data=(X_test,y_test),shuffle=False)
# Out:
# Epoch 1/250
# 22/22 [==============================] - 5s 242ms/step - loss: 0.8997 - accuracy: 0.8679 - jaccard_coef: 0.7233 - val_loss: 0.9143 - val_accuracy: 0.8553 - val_jaccard_coef: 0.6933
# Epoch 2/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.9023 - accuracy: 0.8662 - jaccard_coef: 0.7187 - val_loss: 0.9144 - val_accuracy: 0.8511 - val_jaccard_coef: 0.6863
# Epoch 3/250
# 22/22 [==============================] - 5s 233ms/step - loss: 0.9006 - accuracy: 0.8683 - jaccard_coef: 0.7222 - val_loss: 0.9199 - val_accuracy: 0.8331 - val_jaccard_coef: 0.6797
# Epoch 4/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.9008 - accuracy: 0.8682 - jaccard_coef: 0.7217 - val_loss: 0.9131 - val_accuracy: 0.8547 - val_jaccard_coef: 0.6943
# Epoch 5/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8973 - accuracy: 0.8729 - jaccard_coef: 0.7299 - val_loss: 0.9125 - val_accuracy: 0.8557 - val_jaccard_coef: 0.7064
# Epoch 6/250
# 22/22 [==============================] - 5s 244ms/step - loss: 0.8945 - accuracy: 0.8747 - jaccard_coef: 0.7337 - val_loss: 0.9139 - val_accuracy: 0.8555 - val_jaccard_coef: 0.7114
# Epoch 7/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8934 - accuracy: 0.8773 - jaccard_coef: 0.7381 - val_loss: 0.9133 - val_accuracy: 0.8525 - val_jaccard_coef: 0.7022
# Epoch 8/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8932 - accuracy: 0.8755 - jaccard_coef: 0.7365 - val_loss: 0.9134 - val_accuracy: 0.8553 - val_jaccard_coef: 0.7001
# Epoch 9/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8949 - accuracy: 0.8720 - jaccard_coef: 0.7293 - val_loss: 0.9142 - val_accuracy: 0.8519 - val_jaccard_coef: 0.7088
# Epoch 10/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8944 - accuracy: 0.8745 - jaccard_coef: 0.7336 - val_loss: 0.9183 - val_accuracy: 0.8388 - val_jaccard_coef: 0.6847
# Epoch 11/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8940 - accuracy: 0.8727 - jaccard_coef: 0.7290 - val_loss: 0.9142 - val_accuracy: 0.8566 - val_jaccard_coef: 0.7043
# Epoch 12/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8925 - accuracy: 0.8797 - jaccard_coef: 0.7434 - val_loss: 0.9138 - val_accuracy: 0.8558 - val_jaccard_coef: 0.7107
# Epoch 13/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8913 - accuracy: 0.8796 - jaccard_coef: 0.7428 - val_loss: 0.9111 - val_accuracy: 0.8620 - val_jaccard_coef: 0.7222
# Epoch 14/250
# 22/22 [==============================] - 5s 215ms/step - loss: 0.8904 - accuracy: 0.8823 - jaccard_coef: 0.7480 - val_loss: 0.9104 - val_accuracy: 0.8613 - val_jaccard_coef: 0.7187
# Epoch 15/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8905 - accuracy: 0.8831 - jaccard_coef: 0.7519 - val_loss: 0.9088 - val_accuracy: 0.8640 - val_jaccard_coef: 0.7194
# Epoch 16/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8894 - accuracy: 0.8833 - jaccard_coef: 0.7509 - val_loss: 0.9106 - val_accuracy: 0.8605 - val_jaccard_coef: 0.7200
# Epoch 17/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8902 - accuracy: 0.8787 - jaccard_coef: 0.7407 - val_loss: 0.9247 - val_accuracy: 0.8298 - val_jaccard_coef: 0.6739
# Epoch 18/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8999 - accuracy: 0.8668 - jaccard_coef: 0.7212 - val_loss: 0.9149 - val_accuracy: 0.8541 - val_jaccard_coef: 0.6930
# Epoch 19/250
# 22/22 [==============================] - 5s 239ms/step - loss: 0.8938 - accuracy: 0.8757 - jaccard_coef: 0.7331 - val_loss: 0.9119 - val_accuracy: 0.8504 - val_jaccard_coef: 0.6965
# Epoch 20/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8906 - accuracy: 0.8824 - jaccard_coef: 0.7473 - val_loss: 0.9087 - val_accuracy: 0.8660 - val_jaccard_coef: 0.7285
# Epoch 21/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8880 - accuracy: 0.8851 - jaccard_coef: 0.7516 - val_loss: 0.9090 - val_accuracy: 0.8717 - val_jaccard_coef: 0.7321
# Epoch 22/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8877 - accuracy: 0.8890 - jaccard_coef: 0.7624 - val_loss: 0.9095 - val_accuracy: 0.8634 - val_jaccard_coef: 0.7228
# Epoch 23/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8929 - accuracy: 0.8759 - jaccard_coef: 0.7421 - val_loss: 0.9154 - val_accuracy: 0.8431 - val_jaccard_coef: 0.6995
# Epoch 24/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.9034 - accuracy: 0.8532 - jaccard_coef: 0.6886 - val_loss: 0.9122 - val_accuracy: 0.8545 - val_jaccard_coef: 0.7024
# Epoch 25/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8919 - accuracy: 0.8765 - jaccard_coef: 0.7379 - val_loss: 0.9112 - val_accuracy: 0.8547 - val_jaccard_coef: 0.7118
# Epoch 26/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8896 - accuracy: 0.8774 - jaccard_coef: 0.7371 - val_loss: 0.9106 - val_accuracy: 0.8627 - val_jaccard_coef: 0.7209
# Epoch 27/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8842 - accuracy: 0.8887 - jaccard_coef: 0.7606 - val_loss: 0.9107 - val_accuracy: 0.8628 - val_jaccard_coef: 0.7258
# Epoch 28/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8831 - accuracy: 0.8925 - jaccard_coef: 0.7668 - val_loss: 0.9124 - val_accuracy: 0.8557 - val_jaccard_coef: 0.7173
# Epoch 29/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8829 - accuracy: 0.8940 - jaccard_coef: 0.7696 - val_loss: 0.9118 - val_accuracy: 0.8599 - val_jaccard_coef: 0.7227
# Epoch 30/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8813 - accuracy: 0.8970 - jaccard_coef: 0.7771 - val_loss: 0.9114 - val_accuracy: 0.8606 - val_jaccard_coef: 0.7215
# Epoch 31/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8811 - accuracy: 0.8961 - jaccard_coef: 0.7730 - val_loss: 0.9132 - val_accuracy: 0.8571 - val_jaccard_coef: 0.7183
# Epoch 32/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8805 - accuracy: 0.8980 - jaccard_coef: 0.7784 - val_loss: 0.9100 - val_accuracy: 0.8651 - val_jaccard_coef: 0.7295
# Epoch 33/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8796 - accuracy: 0.9002 - jaccard_coef: 0.7822 - val_loss: 0.9094 - val_accuracy: 0.8694 - val_jaccard_coef: 0.7388
# Epoch 34/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8794 - accuracy: 0.9014 - jaccard_coef: 0.7849 - val_loss: 0.9117 - val_accuracy: 0.8648 - val_jaccard_coef: 0.7336
# Epoch 35/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8795 - accuracy: 0.9000 - jaccard_coef: 0.7818 - val_loss: 0.9120 - val_accuracy: 0.8643 - val_jaccard_coef: 0.7337
# Epoch 36/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8787 - accuracy: 0.9007 - jaccard_coef: 0.7838 - val_loss: 0.9109 - val_accuracy: 0.8679 - val_jaccard_coef: 0.7358
# Epoch 37/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8764 - accuracy: 0.9058 - jaccard_coef: 0.7920 - val_loss: 0.9097 - val_accuracy: 0.8737 - val_jaccard_coef: 0.7528
# Epoch 38/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8745 - accuracy: 0.9088 - jaccard_coef: 0.7998 - val_loss: 0.9102 - val_accuracy: 0.8692 - val_jaccard_coef: 0.7472
# Epoch 39/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8739 - accuracy: 0.9098 - jaccard_coef: 0.8018 - val_loss: 0.9110 - val_accuracy: 0.8689 - val_jaccard_coef: 0.7452
# Epoch 40/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8760 - accuracy: 0.9067 - jaccard_coef: 0.7984 - val_loss: 0.9113 - val_accuracy: 0.8647 - val_jaccard_coef: 0.7391
# Epoch 41/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8877 - accuracy: 0.8807 - jaccard_coef: 0.7435 - val_loss: 0.9124 - val_accuracy: 0.8670 - val_jaccard_coef: 0.7390
# Epoch 42/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8786 - accuracy: 0.9001 - jaccard_coef: 0.7805 - val_loss: 0.9106 - val_accuracy: 0.8674 - val_jaccard_coef: 0.7397
# Epoch 43/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8765 - accuracy: 0.9034 - jaccard_coef: 0.7891 - val_loss: 0.9102 - val_accuracy: 0.8677 - val_jaccard_coef: 0.7365
# Epoch 44/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8738 - accuracy: 0.9101 - jaccard_coef: 0.8021 - val_loss: 0.9110 - val_accuracy: 0.8707 - val_jaccard_coef: 0.7494
# Epoch 45/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8723 - accuracy: 0.9127 - jaccard_coef: 0.8068 - val_loss: 0.9116 - val_accuracy: 0.8678 - val_jaccard_coef: 0.7461
# Epoch 46/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8720 - accuracy: 0.9138 - jaccard_coef: 0.8108 - val_loss: 0.9132 - val_accuracy: 0.8612 - val_jaccard_coef: 0.7364
# Epoch 47/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8716 - accuracy: 0.9141 - jaccard_coef: 0.8098 - val_loss: 0.9155 - val_accuracy: 0.8608 - val_jaccard_coef: 0.7379
# Epoch 48/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8721 - accuracy: 0.9129 - jaccard_coef: 0.8083 - val_loss: 0.9118 - val_accuracy: 0.8665 - val_jaccard_coef: 0.7449
# Epoch 49/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8727 - accuracy: 0.9105 - jaccard_coef: 0.8040 - val_loss: 0.9102 - val_accuracy: 0.8718 - val_jaccard_coef: 0.7509
# Epoch 50/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8710 - accuracy: 0.9150 - jaccard_coef: 0.8140 - val_loss: 0.9087 - val_accuracy: 0.8713 - val_jaccard_coef: 0.7487
# Epoch 51/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8710 - accuracy: 0.9147 - jaccard_coef: 0.8117 - val_loss: 0.9086 - val_accuracy: 0.8745 - val_jaccard_coef: 0.7552
# Epoch 52/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8697 - accuracy: 0.9179 - jaccard_coef: 0.8178 - val_loss: 0.9112 - val_accuracy: 0.8715 - val_jaccard_coef: 0.7523
# Epoch 53/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8695 - accuracy: 0.9187 - jaccard_coef: 0.8196 - val_loss: 0.9102 - val_accuracy: 0.8750 - val_jaccard_coef: 0.7595
# Epoch 54/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8692 - accuracy: 0.9185 - jaccard_coef: 0.8202 - val_loss: 0.9112 - val_accuracy: 0.8729 - val_jaccard_coef: 0.7571
# Epoch 55/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8694 - accuracy: 0.9187 - jaccard_coef: 0.8202 - val_loss: 0.9109 - val_accuracy: 0.8744 - val_jaccard_coef: 0.7591
# Epoch 56/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8690 - accuracy: 0.9188 - jaccard_coef: 0.8176 - val_loss: 0.9137 - val_accuracy: 0.8650 - val_jaccard_coef: 0.7463
# Epoch 57/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8685 - accuracy: 0.9198 - jaccard_coef: 0.8236 - val_loss: 0.9136 - val_accuracy: 0.8640 - val_jaccard_coef: 0.7393
# Epoch 58/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8735 - accuracy: 0.9096 - jaccard_coef: 0.8026 - val_loss: 0.9149 - val_accuracy: 0.8578 - val_jaccard_coef: 0.7267
# Epoch 59/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8729 - accuracy: 0.9117 - jaccard_coef: 0.8046 - val_loss: 0.9111 - val_accuracy: 0.8639 - val_jaccard_coef: 0.7360
# Epoch 60/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8698 - accuracy: 0.9186 - jaccard_coef: 0.8197 - val_loss: 0.9143 - val_accuracy: 0.8596 - val_jaccard_coef: 0.7366
# Epoch 61/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8692 - accuracy: 0.9199 - jaccard_coef: 0.8223 - val_loss: 0.9138 - val_accuracy: 0.8625 - val_jaccard_coef: 0.7417
# Epoch 62/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8682 - accuracy: 0.9208 - jaccard_coef: 0.8248 - val_loss: 0.9111 - val_accuracy: 0.8706 - val_jaccard_coef: 0.7545
# Epoch 63/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8672 - accuracy: 0.9223 - jaccard_coef: 0.8266 - val_loss: 0.9079 - val_accuracy: 0.8777 - val_jaccard_coef: 0.7653
# Epoch 64/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8662 - accuracy: 0.9242 - jaccard_coef: 0.8310 - val_loss: 0.9103 - val_accuracy: 0.8721 - val_jaccard_coef: 0.7573
# Epoch 65/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8661 - accuracy: 0.9254 - jaccard_coef: 0.8335 - val_loss: 0.9098 - val_accuracy: 0.8723 - val_jaccard_coef: 0.7591
# Epoch 66/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8664 - accuracy: 0.9243 - jaccard_coef: 0.8318 - val_loss: 0.9096 - val_accuracy: 0.8733 - val_jaccard_coef: 0.7594
# Epoch 67/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8655 - accuracy: 0.9261 - jaccard_coef: 0.8352 - val_loss: 0.9110 - val_accuracy: 0.8751 - val_jaccard_coef: 0.7626
# Epoch 68/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8648 - accuracy: 0.9278 - jaccard_coef: 0.8391 - val_loss: 0.9138 - val_accuracy: 0.8675 - val_jaccard_coef: 0.7508
# Epoch 69/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8648 - accuracy: 0.9286 - jaccard_coef: 0.8399 - val_loss: 0.9152 - val_accuracy: 0.8617 - val_jaccard_coef: 0.7419
# Epoch 70/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8646 - accuracy: 0.9292 - jaccard_coef: 0.8408 - val_loss: 0.9130 - val_accuracy: 0.8684 - val_jaccard_coef: 0.7517
# Epoch 71/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8647 - accuracy: 0.9289 - jaccard_coef: 0.8407 - val_loss: 0.9121 - val_accuracy: 0.8680 - val_jaccard_coef: 0.7532
# Epoch 72/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8639 - accuracy: 0.9303 - jaccard_coef: 0.8444 - val_loss: 0.9114 - val_accuracy: 0.8699 - val_jaccard_coef: 0.7540
# Epoch 73/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8637 - accuracy: 0.9306 - jaccard_coef: 0.8443 - val_loss: 0.9145 - val_accuracy: 0.8610 - val_jaccard_coef: 0.7441
# Epoch 74/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8635 - accuracy: 0.9311 - jaccard_coef: 0.8447 - val_loss: 0.9176 - val_accuracy: 0.8604 - val_jaccard_coef: 0.7431
# Epoch 75/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8639 - accuracy: 0.9298 - jaccard_coef: 0.8414 - val_loss: 0.9200 - val_accuracy: 0.8559 - val_jaccard_coef: 0.7390
# Epoch 76/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8637 - accuracy: 0.9312 - jaccard_coef: 0.8457 - val_loss: 0.9222 - val_accuracy: 0.8520 - val_jaccard_coef: 0.7313
# Epoch 77/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8641 - accuracy: 0.9305 - jaccard_coef: 0.8443 - val_loss: 0.9203 - val_accuracy: 0.8519 - val_jaccard_coef: 0.7288
# Epoch 78/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8639 - accuracy: 0.9310 - jaccard_coef: 0.8455 - val_loss: 0.9224 - val_accuracy: 0.8481 - val_jaccard_coef: 0.7257
# Epoch 79/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8643 - accuracy: 0.9301 - jaccard_coef: 0.8441 - val_loss: 0.9201 - val_accuracy: 0.8504 - val_jaccard_coef: 0.7264
# Epoch 80/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8679 - accuracy: 0.9247 - jaccard_coef: 0.8331 - val_loss: 0.9157 - val_accuracy: 0.8559 - val_jaccard_coef: 0.7334
# Epoch 81/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8694 - accuracy: 0.9206 - jaccard_coef: 0.8230 - val_loss: 0.9209 - val_accuracy: 0.8398 - val_jaccard_coef: 0.7038
# Epoch 82/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8755 - accuracy: 0.9078 - jaccard_coef: 0.8011 - val_loss: 0.9125 - val_accuracy: 0.8554 - val_jaccard_coef: 0.7120
# Epoch 83/250
# 22/22 [==============================] - 5s 229ms/step - loss: 0.8693 - accuracy: 0.9204 - jaccard_coef: 0.8203 - val_loss: 0.9103 - val_accuracy: 0.8691 - val_jaccard_coef: 0.7505
# Epoch 84/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8666 - accuracy: 0.9261 - jaccard_coef: 0.8353 - val_loss: 0.9102 - val_accuracy: 0.8666 - val_jaccard_coef: 0.7477
# Epoch 85/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8641 - accuracy: 0.9306 - jaccard_coef: 0.8442 - val_loss: 0.9127 - val_accuracy: 0.8652 - val_jaccard_coef: 0.7495
# Epoch 86/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8631 - accuracy: 0.9327 - jaccard_coef: 0.8485 - val_loss: 0.9153 - val_accuracy: 0.8587 - val_jaccard_coef: 0.7399
# Epoch 87/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8630 - accuracy: 0.9330 - jaccard_coef: 0.8501 - val_loss: 0.9160 - val_accuracy: 0.8548 - val_jaccard_coef: 0.7316
# Epoch 88/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8661 - accuracy: 0.9288 - jaccard_coef: 0.8425 - val_loss: 0.9155 - val_accuracy: 0.8553 - val_jaccard_coef: 0.7274
# Epoch 89/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8649 - accuracy: 0.9301 - jaccard_coef: 0.8436 - val_loss: 0.9172 - val_accuracy: 0.8568 - val_jaccard_coef: 0.7349
# Epoch 90/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8632 - accuracy: 0.9333 - jaccard_coef: 0.8492 - val_loss: 0.9156 - val_accuracy: 0.8600 - val_jaccard_coef: 0.7412
# Epoch 91/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8621 - accuracy: 0.9355 - jaccard_coef: 0.8554 - val_loss: 0.9142 - val_accuracy: 0.8639 - val_jaccard_coef: 0.7457
# Epoch 92/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8610 - accuracy: 0.9376 - jaccard_coef: 0.8594 - val_loss: 0.9172 - val_accuracy: 0.8594 - val_jaccard_coef: 0.7430
# Epoch 93/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8606 - accuracy: 0.9387 - jaccard_coef: 0.8615 - val_loss: 0.9111 - val_accuracy: 0.8686 - val_jaccard_coef: 0.7569
# Epoch 94/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8606 - accuracy: 0.9385 - jaccard_coef: 0.8618 - val_loss: 0.9110 - val_accuracy: 0.8690 - val_jaccard_coef: 0.7555
# Epoch 95/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8599 - accuracy: 0.9408 - jaccard_coef: 0.8672 - val_loss: 0.9130 - val_accuracy: 0.8685 - val_jaccard_coef: 0.7561
# Epoch 96/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8594 - accuracy: 0.9416 - jaccard_coef: 0.8678 - val_loss: 0.9133 - val_accuracy: 0.8701 - val_jaccard_coef: 0.7597
# Epoch 97/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8589 - accuracy: 0.9430 - jaccard_coef: 0.8705 - val_loss: 0.9130 - val_accuracy: 0.8753 - val_jaccard_coef: 0.7682
# Epoch 98/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8589 - accuracy: 0.9426 - jaccard_coef: 0.8710 - val_loss: 0.9104 - val_accuracy: 0.8765 - val_jaccard_coef: 0.7680
# Epoch 99/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8580 - accuracy: 0.9446 - jaccard_coef: 0.8749 - val_loss: 0.9113 - val_accuracy: 0.8754 - val_jaccard_coef: 0.7676
# Epoch 100/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8577 - accuracy: 0.9452 - jaccard_coef: 0.8759 - val_loss: 0.9129 - val_accuracy: 0.8768 - val_jaccard_coef: 0.7707
# Epoch 101/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8574 - accuracy: 0.9464 - jaccard_coef: 0.8779 - val_loss: 0.9106 - val_accuracy: 0.8773 - val_jaccard_coef: 0.7715
# Epoch 102/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8572 - accuracy: 0.9469 - jaccard_coef: 0.8796 - val_loss: 0.9100 - val_accuracy: 0.8783 - val_jaccard_coef: 0.7727
# Epoch 103/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8569 - accuracy: 0.9471 - jaccard_coef: 0.8794 - val_loss: 0.9092 - val_accuracy: 0.8764 - val_jaccard_coef: 0.7695
# Epoch 104/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8564 - accuracy: 0.9486 - jaccard_coef: 0.8832 - val_loss: 0.9114 - val_accuracy: 0.8713 - val_jaccard_coef: 0.7616
# Epoch 105/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8558 - accuracy: 0.9495 - jaccard_coef: 0.8847 - val_loss: 0.9119 - val_accuracy: 0.8719 - val_jaccard_coef: 0.7622
# Epoch 106/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8559 - accuracy: 0.9497 - jaccard_coef: 0.8852 - val_loss: 0.9132 - val_accuracy: 0.8685 - val_jaccard_coef: 0.7566
# Epoch 107/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8555 - accuracy: 0.9504 - jaccard_coef: 0.8866 - val_loss: 0.9138 - val_accuracy: 0.8704 - val_jaccard_coef: 0.7602
# Epoch 108/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8556 - accuracy: 0.9505 - jaccard_coef: 0.8877 - val_loss: 0.9122 - val_accuracy: 0.8726 - val_jaccard_coef: 0.7644
# Epoch 109/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8555 - accuracy: 0.9506 - jaccard_coef: 0.8874 - val_loss: 0.9122 - val_accuracy: 0.8736 - val_jaccard_coef: 0.7671
# Epoch 110/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8554 - accuracy: 0.9505 - jaccard_coef: 0.8875 - val_loss: 0.9126 - val_accuracy: 0.8729 - val_jaccard_coef: 0.7653
# Epoch 111/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8555 - accuracy: 0.9503 - jaccard_coef: 0.8871 - val_loss: 0.9123 - val_accuracy: 0.8726 - val_jaccard_coef: 0.7657
# Epoch 112/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8552 - accuracy: 0.9509 - jaccard_coef: 0.8880 - val_loss: 0.9140 - val_accuracy: 0.8713 - val_jaccard_coef: 0.7633
# Epoch 113/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8550 - accuracy: 0.9514 - jaccard_coef: 0.8898 - val_loss: 0.9130 - val_accuracy: 0.8713 - val_jaccard_coef: 0.7636
# Epoch 114/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8553 - accuracy: 0.9504 - jaccard_coef: 0.8873 - val_loss: 0.9163 - val_accuracy: 0.8673 - val_jaccard_coef: 0.7578
# Epoch 115/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8560 - accuracy: 0.9483 - jaccard_coef: 0.8829 - val_loss: 0.9091 - val_accuracy: 0.8804 - val_jaccard_coef: 0.7765
# Epoch 116/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8551 - accuracy: 0.9503 - jaccard_coef: 0.8868 - val_loss: 0.9069 - val_accuracy: 0.8822 - val_jaccard_coef: 0.7786
# Epoch 117/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8553 - accuracy: 0.9500 - jaccard_coef: 0.8868 - val_loss: 0.9098 - val_accuracy: 0.8765 - val_jaccard_coef: 0.7707
# Epoch 118/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8554 - accuracy: 0.9501 - jaccard_coef: 0.8869 - val_loss: 0.9127 - val_accuracy: 0.8702 - val_jaccard_coef: 0.7607
# Epoch 119/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8551 - accuracy: 0.9506 - jaccard_coef: 0.8879 - val_loss: 0.9125 - val_accuracy: 0.8726 - val_jaccard_coef: 0.7633
# Epoch 120/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8551 - accuracy: 0.9505 - jaccard_coef: 0.8877 - val_loss: 0.9144 - val_accuracy: 0.8755 - val_jaccard_coef: 0.7676
# Epoch 121/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8554 - accuracy: 0.9505 - jaccard_coef: 0.8870 - val_loss: 0.9123 - val_accuracy: 0.8787 - val_jaccard_coef: 0.7740
# Epoch 122/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8543 - accuracy: 0.9531 - jaccard_coef: 0.8928 - val_loss: 0.9116 - val_accuracy: 0.8775 - val_jaccard_coef: 0.7741
# Epoch 123/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8543 - accuracy: 0.9532 - jaccard_coef: 0.8928 - val_loss: 0.9131 - val_accuracy: 0.8727 - val_jaccard_coef: 0.7665
# Epoch 124/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8542 - accuracy: 0.9530 - jaccard_coef: 0.8929 - val_loss: 0.9124 - val_accuracy: 0.8723 - val_jaccard_coef: 0.7648
# Epoch 125/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8538 - accuracy: 0.9539 - jaccard_coef: 0.8945 - val_loss: 0.9126 - val_accuracy: 0.8723 - val_jaccard_coef: 0.7655
# Epoch 126/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8535 - accuracy: 0.9547 - jaccard_coef: 0.8970 - val_loss: 0.9110 - val_accuracy: 0.8776 - val_jaccard_coef: 0.7730
# Epoch 127/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8532 - accuracy: 0.9552 - jaccard_coef: 0.8969 - val_loss: 0.9130 - val_accuracy: 0.8774 - val_jaccard_coef: 0.7742
# Epoch 128/250
# 22/22 [==============================] - 5s 215ms/step - loss: 0.8535 - accuracy: 0.9551 - jaccard_coef: 0.8973 - val_loss: 0.9141 - val_accuracy: 0.8715 - val_jaccard_coef: 0.7652
# Epoch 129/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8532 - accuracy: 0.9555 - jaccard_coef: 0.8978 - val_loss: 0.9118 - val_accuracy: 0.8743 - val_jaccard_coef: 0.7692
# Epoch 130/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8529 - accuracy: 0.9558 - jaccard_coef: 0.8991 - val_loss: 0.9122 - val_accuracy: 0.8759 - val_jaccard_coef: 0.7708
# Epoch 131/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8534 - accuracy: 0.9546 - jaccard_coef: 0.8966 - val_loss: 0.9114 - val_accuracy: 0.8770 - val_jaccard_coef: 0.7719
# Epoch 132/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8528 - accuracy: 0.9559 - jaccard_coef: 0.8991 - val_loss: 0.9157 - val_accuracy: 0.8714 - val_jaccard_coef: 0.7647
# Epoch 133/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8526 - accuracy: 0.9567 - jaccard_coef: 0.9003 - val_loss: 0.9157 - val_accuracy: 0.8671 - val_jaccard_coef: 0.7582
# Epoch 134/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8528 - accuracy: 0.9563 - jaccard_coef: 0.9001 - val_loss: 0.9128 - val_accuracy: 0.8725 - val_jaccard_coef: 0.7659
# Epoch 135/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8529 - accuracy: 0.9560 - jaccard_coef: 0.8990 - val_loss: 0.9085 - val_accuracy: 0.8806 - val_jaccard_coef: 0.7782
# Epoch 136/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8525 - accuracy: 0.9568 - jaccard_coef: 0.9007 - val_loss: 0.9099 - val_accuracy: 0.8809 - val_jaccard_coef: 0.7800
# Epoch 137/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8522 - accuracy: 0.9574 - jaccard_coef: 0.9023 - val_loss: 0.9117 - val_accuracy: 0.8752 - val_jaccard_coef: 0.7697
# Epoch 138/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8519 - accuracy: 0.9584 - jaccard_coef: 0.9046 - val_loss: 0.9142 - val_accuracy: 0.8732 - val_jaccard_coef: 0.7676
# Epoch 139/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8519 - accuracy: 0.9584 - jaccard_coef: 0.9044 - val_loss: 0.9138 - val_accuracy: 0.8719 - val_jaccard_coef: 0.7659
# Epoch 140/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8517 - accuracy: 0.9589 - jaccard_coef: 0.9055 - val_loss: 0.9153 - val_accuracy: 0.8736 - val_jaccard_coef: 0.7689
# Epoch 141/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8520 - accuracy: 0.9581 - jaccard_coef: 0.9034 - val_loss: 0.9188 - val_accuracy: 0.8688 - val_jaccard_coef: 0.7633
# Epoch 142/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8524 - accuracy: 0.9578 - jaccard_coef: 0.9030 - val_loss: 0.9149 - val_accuracy: 0.8730 - val_jaccard_coef: 0.7690
# Epoch 143/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8520 - accuracy: 0.9584 - jaccard_coef: 0.9042 - val_loss: 0.9135 - val_accuracy: 0.8750 - val_jaccard_coef: 0.7715
# Epoch 144/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8521 - accuracy: 0.9582 - jaccard_coef: 0.9043 - val_loss: 0.9090 - val_accuracy: 0.8785 - val_jaccard_coef: 0.7749
# Epoch 145/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8521 - accuracy: 0.9581 - jaccard_coef: 0.9036 - val_loss: 0.9126 - val_accuracy: 0.8749 - val_jaccard_coef: 0.7689
# Epoch 146/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8519 - accuracy: 0.9580 - jaccard_coef: 0.9040 - val_loss: 0.9120 - val_accuracy: 0.8754 - val_jaccard_coef: 0.7704
# Epoch 147/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8521 - accuracy: 0.9571 - jaccard_coef: 0.9021 - val_loss: 0.9184 - val_accuracy: 0.8664 - val_jaccard_coef: 0.7574
# Epoch 148/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8518 - accuracy: 0.9584 - jaccard_coef: 0.9039 - val_loss: 0.9166 - val_accuracy: 0.8702 - val_jaccard_coef: 0.7635
# Epoch 149/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8520 - accuracy: 0.9578 - jaccard_coef: 0.9031 - val_loss: 0.9160 - val_accuracy: 0.8725 - val_jaccard_coef: 0.7674
# Epoch 150/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8520 - accuracy: 0.9577 - jaccard_coef: 0.9027 - val_loss: 0.9113 - val_accuracy: 0.8791 - val_jaccard_coef: 0.7761
# Epoch 151/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8517 - accuracy: 0.9590 - jaccard_coef: 0.9058 - val_loss: 0.9110 - val_accuracy: 0.8790 - val_jaccard_coef: 0.7750
# Epoch 152/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8515 - accuracy: 0.9591 - jaccard_coef: 0.9063 - val_loss: 0.9148 - val_accuracy: 0.8707 - val_jaccard_coef: 0.7648
# Epoch 153/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8509 - accuracy: 0.9605 - jaccard_coef: 0.9087 - val_loss: 0.9175 - val_accuracy: 0.8675 - val_jaccard_coef: 0.7605
# Epoch 154/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8512 - accuracy: 0.9599 - jaccard_coef: 0.9081 - val_loss: 0.9151 - val_accuracy: 0.8756 - val_jaccard_coef: 0.7727
# Epoch 155/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8511 - accuracy: 0.9603 - jaccard_coef: 0.9082 - val_loss: 0.9154 - val_accuracy: 0.8745 - val_jaccard_coef: 0.7702
# Epoch 156/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8511 - accuracy: 0.9600 - jaccard_coef: 0.9082 - val_loss: 0.9153 - val_accuracy: 0.8710 - val_jaccard_coef: 0.7659
# Epoch 157/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8509 - accuracy: 0.9608 - jaccard_coef: 0.9097 - val_loss: 0.9180 - val_accuracy: 0.8682 - val_jaccard_coef: 0.7615
# Epoch 158/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8510 - accuracy: 0.9605 - jaccard_coef: 0.9093 - val_loss: 0.9140 - val_accuracy: 0.8730 - val_jaccard_coef: 0.7683
# Epoch 159/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8510 - accuracy: 0.9600 - jaccard_coef: 0.9078 - val_loss: 0.9158 - val_accuracy: 0.8732 - val_jaccard_coef: 0.7689
# Epoch 160/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8509 - accuracy: 0.9604 - jaccard_coef: 0.9089 - val_loss: 0.9148 - val_accuracy: 0.8751 - val_jaccard_coef: 0.7720
# Epoch 161/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8510 - accuracy: 0.9596 - jaccard_coef: 0.9067 - val_loss: 0.9174 - val_accuracy: 0.8691 - val_jaccard_coef: 0.7628
# Epoch 162/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8509 - accuracy: 0.9603 - jaccard_coef: 0.9086 - val_loss: 0.9200 - val_accuracy: 0.8639 - val_jaccard_coef: 0.7549
# Epoch 163/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8506 - accuracy: 0.9610 - jaccard_coef: 0.9098 - val_loss: 0.9158 - val_accuracy: 0.8705 - val_jaccard_coef: 0.7652
# Epoch 164/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8513 - accuracy: 0.9599 - jaccard_coef: 0.9076 - val_loss: 0.9184 - val_accuracy: 0.8690 - val_jaccard_coef: 0.7625
# Epoch 165/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8514 - accuracy: 0.9591 - jaccard_coef: 0.9059 - val_loss: 0.9175 - val_accuracy: 0.8664 - val_jaccard_coef: 0.7571
# Epoch 166/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8518 - accuracy: 0.9588 - jaccard_coef: 0.9052 - val_loss: 0.9144 - val_accuracy: 0.8758 - val_jaccard_coef: 0.7735
# Epoch 167/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8520 - accuracy: 0.9580 - jaccard_coef: 0.9035 - val_loss: 0.9132 - val_accuracy: 0.8734 - val_jaccard_coef: 0.7698
# Epoch 168/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8520 - accuracy: 0.9575 - jaccard_coef: 0.9024 - val_loss: 0.9165 - val_accuracy: 0.8655 - val_jaccard_coef: 0.7567
# Epoch 169/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8512 - accuracy: 0.9595 - jaccard_coef: 0.9067 - val_loss: 0.9129 - val_accuracy: 0.8748 - val_jaccard_coef: 0.7703
# Epoch 170/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8522 - accuracy: 0.9571 - jaccard_coef: 0.9019 - val_loss: 0.9153 - val_accuracy: 0.8753 - val_jaccard_coef: 0.7711
# Epoch 171/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8524 - accuracy: 0.9569 - jaccard_coef: 0.9012 - val_loss: 0.9173 - val_accuracy: 0.8710 - val_jaccard_coef: 0.7650
# Epoch 172/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8528 - accuracy: 0.9562 - jaccard_coef: 0.8999 - val_loss: 0.9185 - val_accuracy: 0.8633 - val_jaccard_coef: 0.7520
# Epoch 173/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8520 - accuracy: 0.9576 - jaccard_coef: 0.9029 - val_loss: 0.9202 - val_accuracy: 0.8662 - val_jaccard_coef: 0.7575
# Epoch 174/250
# 22/22 [==============================] - 5s 225ms/step - loss: 0.8519 - accuracy: 0.9581 - jaccard_coef: 0.9036 - val_loss: 0.9164 - val_accuracy: 0.8725 - val_jaccard_coef: 0.7684
# Epoch 175/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8518 - accuracy: 0.9584 - jaccard_coef: 0.9037 - val_loss: 0.9148 - val_accuracy: 0.8765 - val_jaccard_coef: 0.7756
# Epoch 176/250
# 22/22 [==============================] - 5s 236ms/step - loss: 0.8510 - accuracy: 0.9605 - jaccard_coef: 0.9090 - val_loss: 0.9178 - val_accuracy: 0.8689 - val_jaccard_coef: 0.7629
# Epoch 177/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8507 - accuracy: 0.9609 - jaccard_coef: 0.9102 - val_loss: 0.9148 - val_accuracy: 0.8713 - val_jaccard_coef: 0.7651
# Epoch 178/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8509 - accuracy: 0.9608 - jaccard_coef: 0.9101 - val_loss: 0.9169 - val_accuracy: 0.8693 - val_jaccard_coef: 0.7624
# Epoch 179/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8510 - accuracy: 0.9608 - jaccard_coef: 0.9098 - val_loss: 0.9136 - val_accuracy: 0.8762 - val_jaccard_coef: 0.7729
# Epoch 180/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8506 - accuracy: 0.9615 - jaccard_coef: 0.9108 - val_loss: 0.9165 - val_accuracy: 0.8749 - val_jaccard_coef: 0.7727
# Epoch 181/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8502 - accuracy: 0.9625 - jaccard_coef: 0.9129 - val_loss: 0.9171 - val_accuracy: 0.8738 - val_jaccard_coef: 0.7723
# Epoch 182/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8498 - accuracy: 0.9631 - jaccard_coef: 0.9149 - val_loss: 0.9162 - val_accuracy: 0.8707 - val_jaccard_coef: 0.7675
# Epoch 183/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8495 - accuracy: 0.9638 - jaccard_coef: 0.9164 - val_loss: 0.9162 - val_accuracy: 0.8686 - val_jaccard_coef: 0.7640
# Epoch 184/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8498 - accuracy: 0.9630 - jaccard_coef: 0.9145 - val_loss: 0.9169 - val_accuracy: 0.8711 - val_jaccard_coef: 0.7668
# Epoch 185/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8497 - accuracy: 0.9633 - jaccard_coef: 0.9153 - val_loss: 0.9158 - val_accuracy: 0.8744 - val_jaccard_coef: 0.7721
# Epoch 186/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8500 - accuracy: 0.9625 - jaccard_coef: 0.9139 - val_loss: 0.9163 - val_accuracy: 0.8753 - val_jaccard_coef: 0.7733
# Epoch 187/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8499 - accuracy: 0.9632 - jaccard_coef: 0.9145 - val_loss: 0.9176 - val_accuracy: 0.8730 - val_jaccard_coef: 0.7711
# Epoch 188/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8497 - accuracy: 0.9636 - jaccard_coef: 0.9159 - val_loss: 0.9184 - val_accuracy: 0.8676 - val_jaccard_coef: 0.7630
# Epoch 189/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8496 - accuracy: 0.9636 - jaccard_coef: 0.9156 - val_loss: 0.9161 - val_accuracy: 0.8747 - val_jaccard_coef: 0.7728
# Epoch 190/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8493 - accuracy: 0.9638 - jaccard_coef: 0.9164 - val_loss: 0.9140 - val_accuracy: 0.8754 - val_jaccard_coef: 0.7726
# Epoch 191/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8495 - accuracy: 0.9630 - jaccard_coef: 0.9153 - val_loss: 0.9143 - val_accuracy: 0.8752 - val_jaccard_coef: 0.7729
# Epoch 192/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8494 - accuracy: 0.9633 - jaccard_coef: 0.9150 - val_loss: 0.9201 - val_accuracy: 0.8675 - val_jaccard_coef: 0.7617
# Epoch 193/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8496 - accuracy: 0.9629 - jaccard_coef: 0.9146 - val_loss: 0.9218 - val_accuracy: 0.8677 - val_jaccard_coef: 0.7624
# Epoch 194/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8524 - accuracy: 0.9571 - jaccard_coef: 0.9023 - val_loss: 0.9204 - val_accuracy: 0.8645 - val_jaccard_coef: 0.7539
# Epoch 195/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8698 - accuracy: 0.9189 - jaccard_coef: 0.8202 - val_loss: 0.9133 - val_accuracy: 0.8624 - val_jaccard_coef: 0.7404
# Epoch 196/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8667 - accuracy: 0.9259 - jaccard_coef: 0.8336 - val_loss: 0.9132 - val_accuracy: 0.8660 - val_jaccard_coef: 0.7468
# Epoch 197/250
# 22/22 [==============================] - 5s 231ms/step - loss: 0.8614 - accuracy: 0.9350 - jaccard_coef: 0.8521 - val_loss: 0.9118 - val_accuracy: 0.8727 - val_jaccard_coef: 0.7658
# Epoch 198/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8565 - accuracy: 0.9459 - jaccard_coef: 0.8752 - val_loss: 0.9133 - val_accuracy: 0.8659 - val_jaccard_coef: 0.7551
# Epoch 199/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8531 - accuracy: 0.9536 - jaccard_coef: 0.8941 - val_loss: 0.9114 - val_accuracy: 0.8734 - val_jaccard_coef: 0.7668
# Epoch 200/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8513 - accuracy: 0.9588 - jaccard_coef: 0.9041 - val_loss: 0.9109 - val_accuracy: 0.8762 - val_jaccard_coef: 0.7736
# Epoch 201/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8507 - accuracy: 0.9603 - jaccard_coef: 0.9084 - val_loss: 0.9109 - val_accuracy: 0.8809 - val_jaccard_coef: 0.7808
# Epoch 202/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8503 - accuracy: 0.9610 - jaccard_coef: 0.9097 - val_loss: 0.9102 - val_accuracy: 0.8805 - val_jaccard_coef: 0.7817
# Epoch 203/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8516 - accuracy: 0.9569 - jaccard_coef: 0.9006 - val_loss: 0.9121 - val_accuracy: 0.8733 - val_jaccard_coef: 0.7682
# Epoch 204/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8510 - accuracy: 0.9592 - jaccard_coef: 0.9059 - val_loss: 0.9143 - val_accuracy: 0.8664 - val_jaccard_coef: 0.7560
# Epoch 205/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8504 - accuracy: 0.9610 - jaccard_coef: 0.9098 - val_loss: 0.9124 - val_accuracy: 0.8727 - val_jaccard_coef: 0.7690
# Epoch 206/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8501 - accuracy: 0.9613 - jaccard_coef: 0.9105 - val_loss: 0.9128 - val_accuracy: 0.8750 - val_jaccard_coef: 0.7725
# Epoch 207/250
# 22/22 [==============================] - 5s 247ms/step - loss: 0.8504 - accuracy: 0.9605 - jaccard_coef: 0.9092 - val_loss: 0.9113 - val_accuracy: 0.8783 - val_jaccard_coef: 0.7775
# Epoch 208/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8496 - accuracy: 0.9622 - jaccard_coef: 0.9121 - val_loss: 0.9132 - val_accuracy: 0.8778 - val_jaccard_coef: 0.7784
# Epoch 209/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8493 - accuracy: 0.9629 - jaccard_coef: 0.9138 - val_loss: 0.9126 - val_accuracy: 0.8755 - val_jaccard_coef: 0.7735
# Epoch 210/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8491 - accuracy: 0.9634 - jaccard_coef: 0.9155 - val_loss: 0.9143 - val_accuracy: 0.8768 - val_jaccard_coef: 0.7762
# Epoch 211/250
# 22/22 [==============================] - 5s 237ms/step - loss: 0.8489 - accuracy: 0.9635 - jaccard_coef: 0.9159 - val_loss: 0.9114 - val_accuracy: 0.8819 - val_jaccard_coef: 0.7841
# Epoch 212/250
# 22/22 [==============================] - 5s 235ms/step - loss: 0.8497 - accuracy: 0.9621 - jaccard_coef: 0.9129 - val_loss: 0.9115 - val_accuracy: 0.8764 - val_jaccard_coef: 0.7742
# Epoch 213/250
# 22/22 [==============================] - 5s 238ms/step - loss: 0.8494 - accuracy: 0.9620 - jaccard_coef: 0.9122 - val_loss: 0.9113 - val_accuracy: 0.8826 - val_jaccard_coef: 0.7838
# Epoch 214/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8493 - accuracy: 0.9625 - jaccard_coef: 0.9131 - val_loss: 0.9102 - val_accuracy: 0.8807 - val_jaccard_coef: 0.7798
# Epoch 215/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8489 - accuracy: 0.9634 - jaccard_coef: 0.9154 - val_loss: 0.9116 - val_accuracy: 0.8830 - val_jaccard_coef: 0.7862
# Epoch 216/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8496 - accuracy: 0.9616 - jaccard_coef: 0.9110 - val_loss: 0.9125 - val_accuracy: 0.8793 - val_jaccard_coef: 0.7791
# Epoch 217/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8492 - accuracy: 0.9625 - jaccard_coef: 0.9131 - val_loss: 0.9137 - val_accuracy: 0.8802 - val_jaccard_coef: 0.7815
# Epoch 218/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8488 - accuracy: 0.9633 - jaccard_coef: 0.9150 - val_loss: 0.9142 - val_accuracy: 0.8782 - val_jaccard_coef: 0.7782
# Epoch 219/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8488 - accuracy: 0.9631 - jaccard_coef: 0.9153 - val_loss: 0.9123 - val_accuracy: 0.8817 - val_jaccard_coef: 0.7826
# Epoch 220/250
# 22/22 [==============================] - 6s 256ms/step - loss: 0.8491 - accuracy: 0.9625 - jaccard_coef: 0.9136 - val_loss: 0.9113 - val_accuracy: 0.8844 - val_jaccard_coef: 0.7867
# Epoch 221/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8490 - accuracy: 0.9630 - jaccard_coef: 0.9140 - val_loss: 0.9131 - val_accuracy: 0.8840 - val_jaccard_coef: 0.7872
# Epoch 222/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8494 - accuracy: 0.9617 - jaccard_coef: 0.9112 - val_loss: 0.9131 - val_accuracy: 0.8788 - val_jaccard_coef: 0.7779
# Epoch 223/250
# 22/22 [==============================] - 5s 235ms/step - loss: 0.8492 - accuracy: 0.9624 - jaccard_coef: 0.9125 - val_loss: 0.9180 - val_accuracy: 0.8743 - val_jaccard_coef: 0.7727
# Epoch 224/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8509 - accuracy: 0.9584 - jaccard_coef: 0.9053 - val_loss: 0.9142 - val_accuracy: 0.8771 - val_jaccard_coef: 0.7761
# Epoch 225/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8498 - accuracy: 0.9603 - jaccard_coef: 0.9085 - val_loss: 0.9172 - val_accuracy: 0.8737 - val_jaccard_coef: 0.7676
# Epoch 226/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8493 - accuracy: 0.9618 - jaccard_coef: 0.9116 - val_loss: 0.9153 - val_accuracy: 0.8818 - val_jaccard_coef: 0.7830
# Epoch 227/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8494 - accuracy: 0.9616 - jaccard_coef: 0.9116 - val_loss: 0.9157 - val_accuracy: 0.8821 - val_jaccard_coef: 0.7832
# Epoch 228/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8489 - accuracy: 0.9632 - jaccard_coef: 0.9147 - val_loss: 0.9154 - val_accuracy: 0.8817 - val_jaccard_coef: 0.7829
# Epoch 229/250
# 22/22 [==============================] - 5s 220ms/step - loss: 0.8489 - accuracy: 0.9633 - jaccard_coef: 0.9147 - val_loss: 0.9168 - val_accuracy: 0.8771 - val_jaccard_coef: 0.7764
# Epoch 230/250
# 22/22 [==============================] - 5s 227ms/step - loss: 0.8489 - accuracy: 0.9632 - jaccard_coef: 0.9149 - val_loss: 0.9165 - val_accuracy: 0.8782 - val_jaccard_coef: 0.7771
# Epoch 231/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8488 - accuracy: 0.9634 - jaccard_coef: 0.9159 - val_loss: 0.9128 - val_accuracy: 0.8835 - val_jaccard_coef: 0.7851
# Epoch 232/250
# 22/22 [==============================] - 5s 219ms/step - loss: 0.8486 - accuracy: 0.9638 - jaccard_coef: 0.9160 - val_loss: 0.9139 - val_accuracy: 0.8852 - val_jaccard_coef: 0.7895
# Epoch 233/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8491 - accuracy: 0.9627 - jaccard_coef: 0.9134 - val_loss: 0.9156 - val_accuracy: 0.8801 - val_jaccard_coef: 0.7816
# Epoch 234/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8489 - accuracy: 0.9633 - jaccard_coef: 0.9142 - val_loss: 0.9253 - val_accuracy: 0.8615 - val_jaccard_coef: 0.7478
# Epoch 235/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8555 - accuracy: 0.9492 - jaccard_coef: 0.8847 - val_loss: 0.9199 - val_accuracy: 0.8684 - val_jaccard_coef: 0.7632
# Epoch 236/250
# 22/22 [==============================] - 5s 221ms/step - loss: 0.8539 - accuracy: 0.9525 - jaccard_coef: 0.8929 - val_loss: 0.9121 - val_accuracy: 0.8680 - val_jaccard_coef: 0.7573
# Epoch 237/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8573 - accuracy: 0.9450 - jaccard_coef: 0.8728 - val_loss: 0.9143 - val_accuracy: 0.8726 - val_jaccard_coef: 0.7657
# Epoch 238/250
# 22/22 [==============================] - 5s 222ms/step - loss: 0.8522 - accuracy: 0.9562 - jaccard_coef: 0.8999 - val_loss: 0.9115 - val_accuracy: 0.8773 - val_jaccard_coef: 0.7751
# Epoch 239/250
# 22/22 [==============================] - 5s 218ms/step - loss: 0.8530 - accuracy: 0.9550 - jaccard_coef: 0.8996 - val_loss: 0.9241 - val_accuracy: 0.8540 - val_jaccard_coef: 0.7383
# Epoch 240/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8638 - accuracy: 0.9308 - jaccard_coef: 0.8446 - val_loss: 0.9141 - val_accuracy: 0.8752 - val_jaccard_coef: 0.7653
# Epoch 241/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8571 - accuracy: 0.9450 - jaccard_coef: 0.8726 - val_loss: 0.9143 - val_accuracy: 0.8707 - val_jaccard_coef: 0.7620
# Epoch 242/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8535 - accuracy: 0.9527 - jaccard_coef: 0.8924 - val_loss: 0.9143 - val_accuracy: 0.8705 - val_jaccard_coef: 0.7590
# Epoch 243/250
# 22/22 [==============================] - 5s 228ms/step - loss: 0.8513 - accuracy: 0.9571 - jaccard_coef: 0.8998 - val_loss: 0.9140 - val_accuracy: 0.8729 - val_jaccard_coef: 0.7664
# Epoch 244/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8515 - accuracy: 0.9573 - jaccard_coef: 0.9029 - val_loss: 0.9253 - val_accuracy: 0.8456 - val_jaccard_coef: 0.7263
# Epoch 245/250
# 22/22 [==============================] - 5s 216ms/step - loss: 0.8603 - accuracy: 0.9379 - jaccard_coef: 0.8596 - val_loss: 0.9228 - val_accuracy: 0.8454 - val_jaccard_coef: 0.7259
# Epoch 246/250
# 22/22 [==============================] - 5s 223ms/step - loss: 0.8727 - accuracy: 0.9064 - jaccard_coef: 0.7952 - val_loss: 0.9290 - val_accuracy: 0.8314 - val_jaccard_coef: 0.6945
# Epoch 247/250
# 22/22 [==============================] - 5s 224ms/step - loss: 0.8703 - accuracy: 0.9160 - jaccard_coef: 0.8127 - val_loss: 0.9124 - val_accuracy: 0.8650 - val_jaccard_coef: 0.7453
# Epoch 248/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8601 - accuracy: 0.9363 - jaccard_coef: 0.8550 - val_loss: 0.9200 - val_accuracy: 0.8618 - val_jaccard_coef: 0.7459
# Epoch 249/250
# 22/22 [==============================] - 5s 217ms/step - loss: 0.8606 - accuracy: 0.9352 - jaccard_coef: 0.8517 - val_loss: 0.9160 - val_accuracy: 0.8694 - val_jaccard_coef: 0.7545
# Epoch 250/250
# 22/22 [==============================] - 5s 226ms/step - loss: 0.8549 - accuracy: 0.9488 - jaccard_coef: 0.8849 - val_loss: 0.9124 - val_accuracy: 0.8756 - val_jaccard_coef: 0.7668

# %%
history_a = model_history

loss = history_a.history['loss']
var_loss = history_a.history['val_loss']
epochs = range(1,len(loss)+1)

plt.plot(epochs,loss,'y',label="Training Loss")
plt.plot(epochs,var_loss,'r',label="Validation Loss")
plt.title("Training VS Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
jaccard_coef = history_a.history['jaccard_coef']
val_jaccard_coef = history_a.history['val_jaccard_coef']
epochs = range(1,len(jaccard_coef)+1)

plt.plot(epochs,jaccard_coef,'y',label="Training IoU")
plt.plot(epochs,val_jaccard_coef,'r',label="Validation IoU")
plt.title("Training VS Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 95ms/step

# %%
y_pred_label = np.argmax(y_pred,axis=3)

# %%
y_test_argmax = np.argmax(y_test,axis=3)

# %%
#Comparing Results
test_image_number = random.randint(0,len(y_pred_label))

test_image = X_test[test_image_number]
ground_truth_image = y_test_argmax[test_image_number]

test_image_input = np.expand_dims(test_image,0)
predication = model.predict(test_image_input)
predicted_image = np.argmax(predication,axis=3)

predicted_image = predicted_image[0,:,:]

plt.figure(figsize=(14,8))
plt.subplot(231)
plt.title("Original Image")
plt.imshow(test_image)

plt.subplot(232)
plt.title("Original Masked Image")
plt.imshow(ground_truth_image)

plt.subplot(233)
plt.title("Predicted Masked Image")
plt.imshow(predicted_image)
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
type(predicted_image)
# Out:
# numpy.ndarray

# %%
model.save("Model_satellite_segmentation.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from keras.models import load_model
import os
import cv2
from PIL import Image
import numpy as np
import random
import json
import segmentation_models as sm
from patchify import patchify
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
#PART 2
import tensorflow as tf
from keras.models import Model
from keras.layers import Input,Conv2D,MaxPooling2D, Conv2DTranspose
from keras.layers import concatenate,BatchNormalization,Dropout,Lambda
from keras import backend as K
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical


#Loss function (Focal loss)(Cross entropy loss)
wieghts = [0.166,0.166,0.166,0.166,0.166,0.166]
dice_loss = sm.losses.DiceLoss(class_weights=wieghts)
focal_loss = sm.losses.CategoricalFocalLoss()
total_loss = dice_loss + (1*focal_loss)

def jaccard_coef(y_true,y_pred):
    y_true_flat = tf.keras.backend.flatten(y_true)
    y_pred_flat = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_flat*y_pred_flat)
    final_coef_value = (intersection +1.0)/(tf.keras.backend.sum(y_true_flat)+tf.keras.backend.sum(y_pred_flat)-intersection+1.0)
    return final_coef_value

# %%
saved_model = load_model('/content/Model_satellite_segmentation.h5',
                         custom_objects=({'dice_loss_plus_1focal_loss': total_loss,
                                          'jaccard_coef': jaccard_coef}))

# %%
# saved_model.get_config()

# %%
plt.imshow(Image.open('/content/Satellite-Image-2016-Olympics-Rio-De-Janeiro.jpg'))

# %%
image = Image.open('/content/Satellite-Image-2016-Olympics-Rio-De-Janeiro.jpg')
# image = image.resize((256,256))
image = np.array(image)
image = np.expand_dims(image, 0)

# %%
#  image

# %%
prediction = saved_model.predict(image)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-35-264146d999d8> in <cell line: 1>()
# ----> 1 prediction = saved_model.predict(image)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58         for t in inputs
#      59     ]
# ---> 60     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      61                                         inputs, attrs, num_outputs)
#      62   except core._NotOkStatusException as e:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node model/concatenate/concat defined at (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#
#   File "/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#
#   File "/usr/local/lib/python3.10/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelapp.py", line 619, in start
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/platform/asyncio.py", line 195, in start
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#
#   File "/usr/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#
#   File "/usr/lib/python3.10/asyncio/events.py", line 80, in _run
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 685, in <lambda>
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/ioloop.py", line 738, in _run_callback
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 825, in inner
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 786, in run
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 361, in process_one
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 261, in dispatch_shell
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py", line 539, in execute_request
#
#   File "/usr/local/lib/python3.10/dist-packages/tornado/gen.py", line 234, in wrapper
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 302, in do_execute
#
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/zmqshell.py", line 539, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#
#   File "/usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#
#   File "<ipython-input-35-264146d999d8>", line 1, in <cell line: 1>
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2631, in predict
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2416, in predict_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2401, in step_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2389, in run_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 2357, in predict_step
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py", line 589, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 515, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/functional.py", line 672, in _run_internal_graph
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 65, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/engine/base_layer.py", line 1149, in __call__
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py", line 96, in error_handler
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/merging/base_merge.py", line 196, in call
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/layers/merging/concatenate.py", line 134, in _merge_function
#
#   File "/usr/local/lib/python3.10/dist-packages/keras/src/backend.py", line 3582, in concatenate
#
# ConcatOp : Dimension 2 in both shapes must be equal: shape[0] = [1,128,544,854] vs. shape[1] = [1,128,545,855]
# 	 [[{{node model/concatenate/concat}}]] [Op:__inference_predict_function_2131]

# %%
predicted_image = np.argmax(prediction, axis=3)
predicted_image = predicted_image[0,:,:]

# %%
plt.figure(figsize=(14,8))
plt.subplot(231)
plt.title("Original Image")
plt.imshow(Image.open('/content/Satellite-Image-2016-Olympics-Rio-De-Janeiro.jpg'))
plt.subplot(232)
plt.title("Predicted Image")
plt.imshow(predicted_image)
